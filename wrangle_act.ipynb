# %% [markdown]
# # Project: Wrangle and Analyze Data
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Gathering Data</a></li>
# <li><a href="#eda">Assessing Data</a></li>
# <li><a href="#Cleaning">Cleaning Data</a></li>
# <li><a href="#Analyze">Analyze and visualize Data</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction

# %% [markdown]
# I will wrangle and analyze data archive of Twitter user @dog_rates . and the goal is to reach a good and clear insights of the data.

# %% [markdown]
# <a id='wrangling'></a>
# ## Gathering Data

# %%
# Import all of the packages

import pandas as pd
import numpy as np
import requests 
import re
import os 
import datetime
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
# Now I will download and save images data :

url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open (url.split('/')[-1] , mode = 'wb') as outfile:
    outfile.write(response.content)

#load files:
archive_df = pd.read_csv('twitter-archive-enhanced-2.csv')
images_df = pd.read_csv('image-predictions.tsv' , sep = '\t')
tweet_df = pd.read_json('tweet-json copy' , lines = True)

# %%
#view the first 5 rows in archive_df data
archive_df.head(30)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   892420643555336193                    NaN                  NaN
# 1   892177421306343426                    NaN                  NaN
# 2   891815181378084864                    NaN                  NaN
# 3   891689557279858688                    NaN                  NaN
# 4   891327558926688256                    NaN                  NaN
# 5   891087950875897856                    NaN                  NaN
# 6   890971913173991426                    NaN                  NaN
# 7   890729181411237888                    NaN                  NaN
# 8   890609185150312448                    NaN                  NaN
# 9   890240255349198849                    NaN                  NaN
# 10  890006608113172480                    NaN                  NaN
# 11  889880896479866881                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# ...

# %%
#view the first 5 rows in images_df data
images_df.head(5)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#view the first 5 rows in tweet_df data
tweet_df.head(5)
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
# view the information for archive_df data
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
# view the information for images_df data
images_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# view the information for tweet_df data
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %% [markdown]
# <a id='eda'></a>
# ## Assessing Data

# %%
# First I will do the Assessing data for archive_df
archive_df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
# Now I will look for duplicate values
archive_df.duplicated().sum()
# Out:
# 0

# %%
# Now I will cheek for null value in all columns
archive_df.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# Second I will do the Assessing data for images_df
images_df
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
images_df.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1139  729463711119904772  https://pbs.twimg.com/media/Ch-TXpFXAAAwPGf.jpg
# 1216  743545585370791937  https://pbs.twimg.com/media/ClGawiUWAAAgs0w.jpg
# 1203  741438259667034112  https://pbs.twimg.com/media/CkoeKTPWYAAcWmo.jpg
# 499   675822767435051008  https://pbs.twimg.com/media/CWEBOFYWwAA-O2c.jpg
# 63    667165590075940865  https://pbs.twimg.com/media/CUI_kHBWsAAAef5.jpg
# 1512  786363235746385920  https://pbs.twimg.com/media/Cum5LlfWAAAyPcS.jpg
# 1895  850019790995546112  https://pbs.twimg.com/media/C8vgfTsXgAA561h.jpg
# 1055  714258258790387713  https://pbs.twimg.com/media/CemOGNjWQAEoN7R.jpg
# 1031  711363825979756544  https://pbs.twimg.com/media/Cd9Fn5QUMAAYMT4.jpg
# 945   704480331685040129  https://pbs.twimg.com/media/CcbRIAgXIAQaKHQ.jpg
#
#       img_num                        p1   p1_conf  p1_dog  \
# 1139        1           German_shepherd  0.829307    True
# ...

# %%
# Now I will look for duplicate values
images_df.duplicated().sum()
# Out:
# 0

# %%
# Now I will cheek for null value in all columns
images_df.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
images_df['p1'].value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# coffee_mug              1
# walking_stick           1
# lacewing                1
# tick                    1
# quilt                   1
# Name: p1, Length: 378, dtype: int64

# %%
images_df['p2'].value_counts()
# Out:
# Labrador_retriever    104
# golden_retriever       92
# Cardigan               73
# Chihuahua              44
# Pomeranian             42
#                      ...
# lifeboat                1
# stingray                1
# grey_fox                1
# quail                   1
# hay                     1
# Name: p2, Length: 405, dtype: int64

# %%
images_df['p3'].value_counts()
# Out:
# Labrador_retriever    79
# Chihuahua             58
# golden_retriever      48
# Eskimo_dog            38
# kelpie                35
#                       ..
# chime                  1
# coffeepot              1
# bow_tie                1
# mink                   1
# Band_Aid               1
# Name: p3, Length: 408, dtype: int64

# %%
# Third I will do the Assessing data for tweet_df
tweet_df
# Out:
#                     created_at                  id              id_str  \
# 0    2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1    2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2    2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3    2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4    2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# ...                        ...                 ...                 ...
# 2349 2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# 2350 2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 2351 2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 2352 2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2353 2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
#
#                                               full_text  truncated  \
# ...

# %%
tweet_df.sample(10)
# Out:
#                     created_at                  id              id_str  \
# 1206 2016-04-01 00:58:13+00:00  715704790270025728  715704790270025728
# 877  2016-08-03 00:59:13+00:00  760641137271070720  760641137271070720
# 100  2017-06-08 04:17:07+00:00  872668790621863937  872668790621863936
# 563  2016-11-26 01:31:31+00:00  802323869084381190  802323869084381184
# 346  2017-02-15 17:02:36+00:00  831911600680497154  831911600680497152
# 940  2016-07-12 17:27:23+00:00  752917284578922496  752917284578922496
# 1198 2016-04-03 20:53:33+00:00  716730379797970944  716730379797970944
# 2127 2015-11-27 17:17:44+00:00  670290420111441920  670290420111441920
# 1900 2015-12-09 17:38:19+00:00  674644256330530816  674644256330530816
# 1725 2015-12-24 04:11:37+00:00  679877062409191424  679877062409191424
#
#                                               full_text  truncated  \
# 1206  This is Bentley. He gives kisses back. 11/10 p...      False
# ...

# %%
# view the information for images_df data tweet_df.info()
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %%
# Now I will cheek for null value in all columns
tweet_df.isnull().sum()
# Out:
# created_at                          0
# id                                  0
# id_str                              0
# full_text                           0
# truncated                           0
# display_text_range                  0
# entities                            0
# extended_entities                 281
# source                              0
# in_reply_to_status_id            2276
# in_reply_to_status_id_str        2276
# in_reply_to_user_id              2276
# in_reply_to_user_id_str          2276
# in_reply_to_screen_name          2276
# user                                0
# geo                              2354
# coordinates                      2354
# place                            2353
# contributors                     2354
# is_quote_status                     0
# retweet_count                       0
# favorite_count                      0
# favorited                           0
# retweeted                           0
# possibly_sensitive                143
# ...

# %%
tweet_df.describe()
# Out:
#                  id        id_str  in_reply_to_status_id  \
# count  2.354000e+03  2.354000e+03           7.800000e+01
# mean   7.426978e+17  7.426978e+17           7.455079e+17
# std    6.852812e+16  6.852812e+16           7.582492e+16
# min    6.660209e+17  6.660209e+17           6.658147e+17
# 25%    6.783975e+17  6.783975e+17           6.757419e+17
# 50%    7.194596e+17  7.194596e+17           7.038708e+17
# 75%    7.993058e+17  7.993058e+17           8.257804e+17
# max    8.924206e+17  8.924206e+17           8.862664e+17
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               7.800000e+01         7.800000e+01
# mean                7.455079e+17         2.014171e+16
# std                 7.582492e+16         1.252797e+17
# min                 6.658147e+17         1.185634e+07
# 25%                 6.757419e+17         3.086374e+08
# 50%                 7.038708e+17         4.196984e+09
# 75%                 8.257804e+17         4.196984e+09
# ...

# %% [markdown]
# Quality Issues :
#
#
# 1- Delete extra columns that we don't need.
#
# 2- Fix outliers.
#
# 3- Replace incorrect names and delete empty values.
#
# 4- There are wrong formats because they mix upper and lowercase letters (In the three columns p1, p2 and p3).
#
# 5- Some names in the Name column are valued (a) and (None) and this is incorrect.
#
# 6- Convert the type of tweet_id in and image_predictions_copy from int64 to string.
#
# 7- Removing retweets to list.
#
# 8- ID is intger not string.
#
# 9- I have to merge all dataset.
#
#
# Tidiness Issues :
#
# 1- I see that the following variables (doggo, floofer, pupper, and puppo) should be combined and placed in one column, After that, we delete these four variables.
#
# 2- Merge the tables to make them more clear and organized.

# %% [markdown]
# <a id='Cleaning'></a>
# ## Cleaning Data

# %%
# First I will Cleaning Data for archive_df

#Make a copy of archive_df columns
archive_df_copy= archive_df.copy()
archive_df_copy.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### Quality Issues:
# #### 1- Defin
# ##### I will delete the unimportant columns that do not benefit me, in addition, their presence may affect the quality of the results for the analysis.
# #### 2- Code

# %%
archive_df = archive_df[archive_df.retweeted_status_id.isnull()]
archive_df = archive_df[archive_df.retweeted_status_user_id.isnull()]
archive_df = archive_df[archive_df.retweeted_status_timestamp.isnull()]

drop_columns = ['in_reply_to_status_id','in_reply_to_user_id','source','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp','expanded_urls','rating_numerator','rating_denominator']
archive_df.drop(drop_columns, axis=1,inplace = True)

# %% [markdown]
# #### Test

# %%
archive_df_copy.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
# 7  890729181411237888                    NaN                  NaN
# 8  890609185150312448                    NaN                  NaN
# 9  890240255349198849                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# ...

# %% [markdown]
# #### 1- Defin
# ##### Removing retweets to list ( I will drop columns : ( 'in_reply_to_status_id' , 'in_reply_to_user_id' , 'retweeted_status_id' , 'retweeted_status_user_id' , 'retweeted_status_timestamp')
# #### 2- Code

# %%
archive_df_copy = archive_df_copy.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'], axis=1)

# %% [markdown]
# #### Test

# %%
archive_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   doggo               2356 non-null   object
#  9   floofer             2356 non-null   object
#  10  pupper              2356 non-null   object
#  11  puppo               2356 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 221.0+ KB

# %% [markdown]
# #### 1- Defin
# ##### the following variables (doggo, floofer, pupper, and puppo) should be combined and placed in one column, After that, we delete these four variables.
# #### 2- Code

# %%
# Extract doggo, floofer, pupper and puppo columns into new 'stages_of_dogs' column 

archive_df.loc[(archive_df[['doggo', 'floofer', 'pupper', 'puppo']] != 'None'
                 ).sum(axis=1) > 1]


#archive_df_copy['Type_dogs'] = archive_df_copy['text'].str.extract('(doggo|floofer|pupper|puppo)')
#archive_df_copy= archive_df_copy.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1)
# Out:
#                 tweet_id                  timestamp  \
# 191   855851453814013952  2017-04-22 18:31:02 +0000
# 200   854010172552949760  2017-04-17 16:34:26 +0000
# 460   817777686764523521  2017-01-07 16:59:28 +0000
# 531   808106460588765185  2016-12-12 00:29:28 +0000
# 565   802265048156610565  2016-11-25 21:37:47 +0000
# 575   801115127852503040  2016-11-22 17:28:25 +0000
# 705   785639753186217984  2016-10-11 00:34:48 +0000
# 733   781308096455073793  2016-09-29 01:42:20 +0000
# 889   759793422261743616  2016-07-31 16:50:42 +0000
# 956   751583847268179968  2016-07-09 01:08:47 +0000
# 1063  741067306818797568  2016-06-10 00:39:48 +0000
# 1113  733109485275860992  2016-05-19 01:38:16 +0000
#
#                                                    text    name  doggo  \
# 191   Here's a puppo participating in the #ScienceMa...    None  doggo
# 200   At first I thought this was a shy doggo, but i...    None  doggo
# ...

# %% [markdown]
# #### 3- Test

# %%
archive_df_copy.head(10)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
# 5  891087950875897856  2017-07-29 00:08:17 +0000
# 6  890971913173991426  2017-07-28 16:27:12 +0000
# 7  890729181411237888  2017-07-28 00:22:40 +0000
# 8  890609185150312448  2017-07-27 16:25:51 +0000
# 9  890240255349198849  2017-07-26 15:59:51 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# #### 1- Defin
# ##### I noticed that there is a wrong datatype on tweet-id and timestamp tweet_id, timestamp so it needs to be fixed
# #### 2- Code

# %%
archive_df_copy['tweet_id'] = archive_df_copy['tweet_id'].astype(str)
archive_df_copy.timestamp = pd.to_datetime(archive_df_copy['timestamp'])
archive_df_copy.rename(columns={"timestamp":'tweet_date'},inplace=True)

# %% [markdown]
# #### Test

# %%
print (archive_df_copy['tweet_id'].dtypes)
print (archive_df_copy['tweet_date'].dtypes)
# Out:
# object
# datetime64[ns, UTC]

# %%
archive_df_copy.head(10)
# Out:
#              tweet_id                tweet_date  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
# 5  891087950875897856 2017-07-29 00:08:17+00:00
# 6  890971913173991426 2017-07-28 16:27:12+00:00
# 7  890729181411237888 2017-07-28 00:22:40+00:00
# 8  890609185150312448 2017-07-27 16:25:51+00:00
# 9  890240255349198849 2017-07-26 15:59:51+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
# Now I will Create a copy of images_df
images_df_copy = images_df.copy()
images_df_copy.head(10)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6  666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8  666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# ...

# %% [markdown]
# #### 1- Defin
# ##### In the three columns p1, p2 and p3 there are some uppercase and lowercase letters so I will make them in a standard character format
# #### 2- Code

# %%
images_df_copy['p1'] = images_df_copy['p1'].str.lower()
images_df_copy['p2'] = images_df_copy['p2'].str.lower()
images_df_copy['p3'] = images_df_copy['p3'].str.lower()

# %% [markdown]
# #### Test

# %%
images_df_copy['p1'].head(10)
# Out:
# 0    welsh_springer_spaniel
# 1                   redbone
# 2           german_shepherd
# 3       rhodesian_ridgeback
# 4        miniature_pinscher
# 5      bernese_mountain_dog
# 6                box_turtle
# 7                      chow
# 8             shopping_cart
# 9          miniature_poodle
# Name: p1, dtype: object

# %%
images_df_copy['p2'].head(10)
# Out:
# 0                collie
# 1    miniature_pinscher
# 2              malinois
# 3               redbone
# 4            rottweiler
# 5      english_springer
# 6            mud_turtle
# 7       tibetan_mastiff
# 8       shopping_basket
# 9              komondor
# Name: p2, dtype: object

# %%
images_df_copy['p3'].head(10)
# Out:
# 0              shetland_sheepdog
# 1            rhodesian_ridgeback
# 2                     bloodhound
# 3             miniature_pinscher
# 4                       doberman
# 5     greater_swiss_mountain_dog
# 6                       terrapin
# 7                       fur_coat
# 8               golden_retriever
# 9    soft-coated_wheaten_terrier
# Name: p3, dtype: object

# %% [markdown]
# #### 1- Defin
# ##### Convert the type of tweet_id from int64 to string
# #### 2- Code

# %%
images_df_copy['tweet_id'] = images_df_copy['tweet_id'].astype('str')

# %% [markdown]
# #### 3- Test

# %%
print(images_df_copy['tweet_id'].dtype)
# Out:
# object

# %%
#Now I will Create a copy of tweet_df
tweet_df_copy = tweet_df.copy()
tweet_df.head(10)
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# 5 2017-07-29 00:08:17+00:00  891087950875897856  891087950875897856
# 6 2017-07-28 16:27:12+00:00  890971913173991426  890971913173991424
# 7 2017-07-28 00:22:40+00:00  890729181411237888  890729181411237888
# 8 2017-07-27 16:25:51+00:00  890609185150312448  890609185150312448
# 9 2017-07-26 15:59:51+00:00  890240255349198849  890240255349198848
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# ...

# %% [markdown]
# #### 1- Defin
# ##### At first we will delete all the columns that we do not need and that will affect the quality of the analysis.
# #### 2- Code

# %%
tweet_df_copy.drop(columns=['created_at','full_text','truncated','display_text_range','entities'
    ,'extended_entities','in_reply_to_status_id','in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str' ,'in_reply_to_screen_name','user','geo','coordinates','favorited','retweeted','possibly_sensitive','possibly_sensitive_appealable','lang'
    ,'retweeted_status','quoted_status_id','quoted_status_id_str','quoted_status','place','contributors','is_quote_status'],inplace=True)

# %% [markdown]
# #### 3- Test

# %%
tweet_df_copy.describe()
# Out:
#                  id        id_str  retweet_count  favorite_count
# count  2.354000e+03  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17  7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16  6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17  6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17  6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17  7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17  7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17  8.924206e+17   79515.000000   132810.000000

# %%
tweet_df_copy.head(10)
# Out:
#                    id              id_str  \
# 0  892420643555336193  892420643555336192
# 1  892177421306343426  892177421306343424
# 2  891815181378084864  891815181378084864
# 3  891689557279858688  891689557279858688
# 4  891327558926688256  891327558926688256
# 5  891087950875897856  891087950875897856
# 6  890971913173991426  890971913173991424
# 7  890729181411237888  890729181411237888
# 8  890609185150312448  890609185150312448
# 9  890240255349198849  890240255349198848
#
#                                               source  retweet_count  \
# 0  <a href="http://twitter.com/download/iphone" r...           8853
# 1  <a href="http://twitter.com/download/iphone" r...           6514
# 2  <a href="http://twitter.com/download/iphone" r...           4328
# 3  <a href="http://twitter.com/download/iphone" r...           8964
# 4  <a href="http://twitter.com/download/iphone" r...           9774
# 5  <a href="http://twitter.com/download/iphone" r...           3261
# ...

# %%
tweet_df_copy.isnull().sum()
# Out:
# id                0
# id_str            0
# source            0
# retweet_count     0
# favorite_count    0
# dtype: int64

# %% [markdown]
# #### 1- Defin
# ##### Now I'm going to change the column name id _str to tweet_id and then I'll change its type to String .
# #### 2- Code

# %%
tweet_df_copy.rename(columns={'id_str':'tweet_id'},inplace=True)

# %%
tweet_df_copy['tweet_id'] = tweet_df_copy['tweet_id'].astype('str')

# %% [markdown]
# #### 3- Test

# %%
tweet_df_copy.head(10)
# Out:
#                    id            tweet_id  \
# 0  892420643555336193  892420643555336192
# 1  892177421306343426  892177421306343424
# 2  891815181378084864  891815181378084864
# 3  891689557279858688  891689557279858688
# 4  891327558926688256  891327558926688256
# 5  891087950875897856  891087950875897856
# 6  890971913173991426  890971913173991424
# 7  890729181411237888  890729181411237888
# 8  890609185150312448  890609185150312448
# 9  890240255349198849  890240255349198848
#
#                                               source  retweet_count  \
# 0  <a href="http://twitter.com/download/iphone" r...           8853
# 1  <a href="http://twitter.com/download/iphone" r...           6514
# 2  <a href="http://twitter.com/download/iphone" r...           4328
# 3  <a href="http://twitter.com/download/iphone" r...           8964
# 4  <a href="http://twitter.com/download/iphone" r...           9774
# 5  <a href="http://twitter.com/download/iphone" r...           3261
# ...

# %%
tweet_df_copy.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
tweet_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2354 non-null   int64
#  1   tweet_id        2354 non-null   object
#  2   source          2354 non-null   object
#  3   retweet_count   2354 non-null   int64
#  4   favorite_count  2354 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 92.1+ KB

# %%
print(tweet_df_copy['tweet_id'].dtype)
# Out:
# object

# %% [markdown]
# #### 1- Defin
# ##### After I changed the column type tweet_id I will also change the name of the column type source from source to category .
# #### 2- Code

# %%
tweet_df_copy['source'] = tweet_df_copy['source'].astype('category')

# %% [markdown]
# ### 3- Test

# %%
print(tweet_df_copy['source'].dtype)
# Out:
# category

# %% [markdown]
# #### 1- Defin
# ##### merge all dataset
# #### 2- Code

# %%
# Now I will merge inside merge_df
merge_df = pd.merge(archive_df_copy,tweet_df_copy , on='tweet_id' , how ='left')
merge_df = pd.merge(merge_df,images_df_copy,on='tweet_id',how='left')

# %% [markdown]
# ### 3- Test

# %%
merge_df.head(50)
# Out:
#               tweet_id                tweet_date  \
# 0   892420643555336193 2017-08-01 16:23:56+00:00
# 1   892177421306343426 2017-08-01 00:17:27+00:00
# 2   891815181378084864 2017-07-31 00:18:03+00:00
# 3   891689557279858688 2017-07-30 15:58:51+00:00
# 4   891327558926688256 2017-07-29 16:00:24+00:00
# 5   891087950875897856 2017-07-29 00:08:17+00:00
# 6   890971913173991426 2017-07-28 16:27:12+00:00
# 7   890729181411237888 2017-07-28 00:22:40+00:00
# 8   890609185150312448 2017-07-27 16:25:51+00:00
# 9   890240255349198849 2017-07-26 15:59:51+00:00
# 10  890006608113172480 2017-07-26 00:31:25+00:00
# 11  889880896479866881 2017-07-25 16:11:53+00:00
# 12  889665388333682689 2017-07-25 01:55:32+00:00
# 13  889638837579907072 2017-07-25 00:10:02+00:00
# 14  889531135344209921 2017-07-24 17:02:04+00:00
# 15  889278841981685760 2017-07-24 00:19:32+00:00
# 16  888917238123831296 2017-07-23 00:22:39+00:00
# 17  888804989199671297 2017-07-22 16:56:37+00:00
# ...

# %%
clean_df = merge_df.copy()

# %%
clean_df.describe()
# Out:
#        rating_numerator  rating_denominator            id  retweet_count  \
# count       2356.000000         2356.000000  1.518000e+03    1518.000000
# mean          13.126486           10.455433  7.386500e+17    2971.322134
# std           45.876648            6.745237  6.699942e+16    4867.362390
# min            0.000000            0.000000  6.660293e+17       2.000000
# 25%           10.000000           10.000000  6.767853e+17     607.250000
# 50%           11.000000           10.000000  7.145456e+17    1389.000000
# 75%           12.000000           10.000000  7.904331e+17    3493.500000
# max         1776.000000          170.000000  8.918152e+17   56625.000000
#
#        favorite_count      img_num      p1_conf       p2_conf       p3_conf
# count     1518.000000  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean      7752.137681     1.203855     0.594548  1.345886e-01  6.032417e-02
# std      10966.529752     0.561875     0.271174  1.006657e-01  5.090593e-02
# ...

# %%
# Now I will storing the cleaned data
clean_df.to_csv('twitter_archive_master.csv' , index = False)

# %% [markdown]
# <a id='Analyz'></a>
# ## Analyze and visualize Data

# %%
# Import all of the packages

import pandas as pd
import numpy as np
import requests 
import re
import os 
import datetime
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
visualization_df = pd.read_csv('twitter_archive_master.csv')

# %%
visualization_df
# Out:
#                 tweet_id                 tweet_date  \
# 0     892420643555336193  2017-08-01 16:23:56+00:00
# 1     892177421306343426  2017-08-01 00:17:27+00:00
# 2     891815181378084864  2017-07-31 00:18:03+00:00
# 3     891689557279858688  2017-07-30 15:58:51+00:00
# 4     891327558926688256  2017-07-29 16:00:24+00:00
# ...                  ...                        ...
# 2351  666049248165822465  2015-11-16 00:24:50+00:00
# 2352  666044226329800704  2015-11-16 00:04:52+00:00
# 2353  666033412701032449  2015-11-15 23:21:54+00:00
# 2354  666029285002620928  2015-11-15 23:05:30+00:00
# 2355  666020888022790149  2015-11-15 22:32:08+00:00
#
#                                                source_x  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# ...

# %%
# have copy from the cleaned data 
visualization_df = archive_df_copy.copy()

# %%
visualization_df
# Out:
#                 tweet_id                tweet_date  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2351  666049248165822465 2015-11-16 00:24:50+00:00
# 2352  666044226329800704 2015-11-16 00:04:52+00:00
# 2353  666033412701032449 2015-11-15 23:21:54+00:00
# 2354  666029285002620928 2015-11-15 23:05:30+00:00
# 2355  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
#  insight (1) : The (rating numerator) shows us the data.

# %%
plt.title('rating numerator', size=13)
sns.countplot(data=visualization_df, x='rating_numerator')

# %% [markdown]
# We notice that the highest value is at 12, followed by 11, 10, and then 13. It is also noticed that the curve increased rapidly and then fell sharply. At point 14, the streak of decline and at point 15 and 16 it became almost equal to zero.

# %% [markdown]
#  insight (2) : The following figure shows us the source of the tweets.

# %%
visualization_df['source'].value_counts().sort_values(ascending=False)
# colors=sns.color_palette('pastel')[0:5]
colors = ['#28A2AE' , '#DF684D' , '#3AA761' , '#AAA2AE' ]
visualization_df['source'].value_counts()[0:5].sort_values(ascending=False).plot.pie(figsize=(5,6),colors=colors,autopct='%1.0f%%', startangle = 90)
plt.title('the source of the tweets')
plt.show()

# %% [markdown]
# I noticed here that the source is long and untidy and difficult to read, so I have to fix it.

# %%
visualization_df['source'] = visualization_df["source"].str.replace(r'<(?:a\b[^>]*>|/a>)', '')

# %%
visualization_df['source'].value_counts()
# Out:
# Twitter for iPhone     2221
# Vine - Make a Scene      91
# Twitter Web Client       33
# TweetDeck                11
# Name: source, dtype: int64

# %%
visualization_df.head()
# Out:
#              tweet_id                tweet_date              source  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# ...

# %%
visualization_df['source'].value_counts().sort_values(ascending=False)
# colors=sns.color_palette('pastel')[0:5]
colors = ['#28A2AE' , '#DF684D' , '#3AA761' , '#AAA2AE' ]
visualization_df['source'].value_counts()[0:5].sort_values(ascending=False).plot.pie(figsize=(5,6),colors=colors,autopct='%1.0f%%', startangle = 90)
plt.title('The source of the tweets')
plt.show()

# %% [markdown]
# The order is :
#
# 1- (iPhone) by 94.2699491% .
#
# 2- (Vine - Make a Scene) by 3.86247878% .
#
# 3- (Twitter Web Client) by 1.40067912% .
#
# 4- (TweetDeck) by 0.46689304% .

# %% [markdown]
#  insight (3) : The relationship between (rating_numerator) and (tweet_date) .

# %%
visualization_df.plot(kind='scatter',x='rating_numerator',y='tweet_date',color='lightpink')
plt.xlabel('Rating')
plt.ylabel('Tweet Date')
plt.title('Relationship : Rating AND Tweet Date')
# Out:
# Text(0.5, 1.0, 'Relationship : Rating AND Tweet Date')

# %% [markdown]
# We note that the graph is almost constant and the values are close.

# %% [markdown]
# insight (4) : The Count of (rating_denominator) .

# %%
visualization_df['rating_denominator'].plot()
plt.style.use('seaborn-darkgrid')
plt.xlabel('rating')
plt.ylabel('Count')
plt.savefig('Count of rating.png')
plt.show()

# %% [markdown]
# We notice that the data increases dramatically between approximately 400 and 1900, especially at 1100 and then 900

# %% [markdown]
# insight (5) : The Count of (rating_numerator) .

# %%
visualization_df['rating_numerator'].plot()
plt.style.use('seaborn-darkgrid')
plt.xlabel('rating')
plt.ylabel('Count')
plt.savefig('Count of rating.png')
plt.show()

# %% [markdown]
# We note that the data is spread in all points equally to some extent, but it increases in 3 or 4 points only.. The most increasing point is 999
